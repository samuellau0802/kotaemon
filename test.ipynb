# %%
import requests

# Define the URL and headers
url = 'https://s.jina.ai/When%20was%20Jina%20AI%20founded%3F'
headers = {
    "Authorization": "Bearer jina_94fb668660ff40a9bad3955ae630f7df8ac2bek0kZ7Dw3L228Y63NeKkjWC",
    "X-With-Links-Summary": "true",
    "Accept": "application/json"
}

# Make the GET request
response = requests.get(url, headers=headers)

# Check the response
if response.status_code == 200:
    data = response.json()  # Parse JSON response
    print(data)
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'code': 200, 'status': 20000, 'data': [{'title': 'Jina AI - Your Search Foundation, Supercharged.', 'url': 'https://jina.ai/', 'content': 'Jina AI - Your Search Foundation, Supercharged.\n===============\n  \n\n[_![Image 1](https://jina.ai/Jina%20-%20Dark.svg)_](https://jina.ai/)\n\n_search_[_notifications_ News](https://jina.ai/news)Products _![Image 2](https://jina.ai/J.svg)_Company\n\nYour Search Foundation Supercharged.\n====================================\n\n_code_API\n\n* * *\n\n[_handshake_Contact](https://jina.ai/contact-sales)\n\n* * *\n\n[_forum_Community](https://discord.jina.ai/)\n\nOur customers\n\n![Image 3](https://jina.ai/assets/logo_sendbird.9e2f85d1.svg)\n\n![Image 4](blob:https://jina.ai/f68c893139dd38bbdd72e8e2ac13d66b)\n\n![Image 5](https://jina.ai/assets/logo-stability_ai.277f9015.svg)\n\n![Image 6](https://jina.ai/assets/logo-Tencent.ff153e7e.svg)\n\n![Image 7](https://jina.ai/assets/logo_monstar_lab.38e90dd2.png)\n\n![Image 8](blob:https://jina.ai/c491b6cd3b
# ...

# %%
data['data'][4]
# Out:
# {'title': 'GitHub - jina-ai/jina: ☁️ Build multimodal AI applications with cloud-native stack',
#  'url': 'https://github.com/jina-ai/jina',
# ...

# %%
from PIL import Image 
import io

img_base64 = "data:image/png;base64,..."

# %%
import base64
from PIL import Image, ImageFile
from io import BytesIO


# Strip the prefix if it exists
if img_base64.startswith("data:image/png;base64,"):
    img_base64 = img_base64.replace("data:image/png;base64,", "")

# Decode the base64 image string
image_data = base64.b64decode(img_base64)

# Handle truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Open the image using PIL
try:
    image = Image.open(BytesIO(image_data))
    # Display the image (optional, for Jupyter Notebook)
    image.show()
except OSError as e:
    print(f"Error opening image: {e}")
